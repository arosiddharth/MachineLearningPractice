# %% [markdown]
# # KNN Classification

# %%
# Using car evaluation data from UCI
# https://archive.ics.uci.edu/ml/datasets/Car+Evaluation

# %%
# adding feature names to the data file as pandas use the first line as the name of the attributes/features in the dataset
# feature names are: "buying,maint,door,persons,lug_boot,safety,class"
# more info about the features is given on the link from where the dataset is taken

# %%
# importing the essential files from sklearn
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model,preprocessing

# %%
# importing data from car.data file using pandas read csv function as the .data file is also comma separated
cardata=pd.read_csv("C:\\Users\\SID\\pythonpractice\\MLcourse\\data\\car.data")

# %%
# viewing the top 5 data lines
cardata.head()
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc

# %%
cardata["buying"]
# Out:
# 0       vhigh
# 1       vhigh
# 2       vhigh
# 3       vhigh
# 4       vhigh
#         ...
# 1723      low
# 1724      low
# 1725      low
# 1726      low
# 1727      low
# Name: buying, Length: 1728, dtype: object

# %%
# converting non numeric data to numeric data and changing vhigh,small etc to some relevant numeric values
# label encoding using sklearn's built in preprocessing mechanism called labelEncoder object and saving it to a new variable "le" same way as we save pandas as pd
le=preprocessing.LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
# fit_transform() method takes list of column and return an array from the original pandas dataframe
tr_buying=le.fit_transform(list(cardata["buying"])) # transforming buying column into a list then transform them using fit_tranform method

# %%
# data is segregated into the categories that exist in the cardata, vhigh is replaced by  3, low is replaced by 1 etc i.e. some integer value for all the classes
tr_buying
# Out:
# array([3, 3, 3, ..., 1, 1, 1], dtype=int64)

# %%
cardata["buying"]
# Out:
# 0       vhigh
# 1       vhigh
# 2       vhigh
# 3       vhigh
# 4       vhigh
#         ...
# 1723      low
# 1724      low
# 1725      low
# 1726      low
# 1727      low
# Name: buying, Length: 1728, dtype: object

# %%
# transforming other columns into relevant numeric data
tr_maint = le.fit_transform(list(cardata["maint"]))
tr_door = le.fit_transform(list(cardata["door"]))
tr_persons = le.fit_transform(list(cardata["persons"]))
tr_lug_boot = le.fit_transform(list(cardata["lug_boot"]))
tr_safety = le.fit_transform(list(cardata["safety"]))
tr_cls = le.fit_transform(list(cardata["class"]))

# %%
# combining the features together using python's built in function zip which joins list into tuple which further has to be transformed to list or dict (possible if only 2 element are zipped)
X=list(zip(tr_buying,tr_maint,tr_door,tr_persons,tr_lug_boot,tr_safety)) # features i.e. the attributes used to predict the labels
y=list(tr_cls) # labels i.e. the values which are to be predicted/classified

# %%
# dividing the data into training and testing data
x_train,x_test,y_train,y_test=sklearn.model_selection.train_test_split(X,y,test_size=0.1)

# %%
len(x_train)
# Out:
# 1555

# %%
len(x_test)
# Out:
# 173

# %%
model=KNeighborsClassifier(n_neighbors=7) # using generic name "model" as it is of not much use to pickle this model

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
# accuracy score changes as per the K hyperparamters for 5 it is close to 90 but for 3 it is around 80 and for 7 it is around 93 although it depends on the train test split
acc=model.score(x_test,y_test)

# %%
acc
# Out:
# 0.9364161849710982

# %%
# making predictions/classification the test data with KNNClassifier with 7 closest neighbor which we finalize after checking for a few times could be better but that depends on the train test split
predicted = model.predict(x_test)

# %%
predicted
# Out:
# array([2, 2, 2, 0, 2, 2, 2, 0, 2, 0, 2, 0, 2, 0, 2, 2, 2, 0, 3, 0, 2, 2,
#        2, 2, 2, 2, 0, 2, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 0, 2,
#        2, 0, 1, 0, 2, 2, 0, 2, 2, 2, 3, 2, 2, 2, 0, 2, 2, 2, 0, 0, 2, 0,
#        0, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2,
#        2, 0, 2, 0, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2,
#        0, 2, 2, 0, 2, 0, 2, 2, 0, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2,
#        2, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 0, 0, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2],
#       dtype=int64)

# %%
# to  use actual labels instead of numbers 
names=["unacc","acc","good","vgood"]

# %%
# to view predicted values, the data and actual values on test data in transformed form
for i in range(len(predicted)):
    print(f"Predicted: {predicted[i]} Data: {x_test[i]} Actual: {y_test[i]}")
# Out:
# Predicted: 2 Data: (0, 0, 2, 1, 2, 2) Actual: 2
# Predicted: 2 Data: (2, 1, 2, 0, 0, 1) Actual: 2
# Predicted: 2 Data: (0, 2, 1, 0, 1, 1) Actual: 2
# Predicted: 0 Data: (2, 0, 1, 2, 0, 0) Actual: 0
# Predicted: 2 Data: (0, 2, 3, 0, 2, 1) Actual: 2
# Predicted: 2 Data: (3, 2, 3, 2, 1, 1) Actual: 2
# Predicted: 2 Data: (3, 0, 3, 2, 1, 0) Actual: 2
# Predicted: 0 Data: (1, 0, 1, 1, 1, 2) Actual: 0
# Predicted: 2 Data: (3, 1, 0, 1, 2, 2) Actual: 2
# Predicted: 0 Data: (0, 1, 1, 1, 0, 0) Actual: 0
# Predicted: 2 Data: (3, 2, 0, 1, 2, 1) Actual: 2
# Predicted: 0 Data: (2, 2, 2, 2, 2, 0) Actual: 0
# Predicted: 2 Data: (3, 1, 0, 0, 0, 2) Actual: 2
# Predicted: 0 Data: (3, 1, 1, 2, 0, 2) Actual: 0
# Predicted: 2 Data: (0, 2, 3, 2, 2, 1) Actual: 2
# Predicted: 2 Data: (1, 3, 2, 0, 1, 2) Actual: 2
# Predicted: 2 Data: (0, 1, 3, 1, 1, 1) Actual: 2
# Predicted: 0 Data: (2, 2, 0, 2, 0, 0) Actual: 3
# Predicted: 3 Data: (1, 1, 2, 2, 0, 0) Actual: 3
# Predicted: 0 Data: (1, 3, 1, 2, 0, 0) Actual: 0
# Predicted: 2 Data: (0, 0, 3, 2, 0, 1) Actual: 2
# Predicted: 2 Data: (1, 3, 3, 0, 1, 2) Actual: 2
# Predicted: 2 Data: (2, 1, 0, 1, 1, 1) Actual: 2
# Predicted: 2 Data: (2, 3, 2, 2, 1, 1) Actual: 2
# Predicted: 2 Data: (3, 2, 1, 2, 2, 2) Actual: 2
# Predicted: 2 Data: (1, 3, 2, 0, 1, 0) Actual: 2
# Predicted: 0 Data: (1, 1, 3, 2, 1, 2) Actual: 1
# Predicted: 2 Data: (3, 3, 2, 2, 0, 0) Actual: 2
# Predicted: 0 Data: (2, 3, 3, 1, 0, 2) Actual: 0
# Predicted: 0 Data: (1, 0, 1, 1, 2, 0) Actual: 0
# Predicted: 0 Data: (0, 0, 2, 2, 1, 0) Actual: 0
# Predicted: 2 Data: (2, 1, 3, 0, 1, 2) Actual: 2
# Predicted: 2 Data: (0, 0, 1, 1, 2, 2) Actual: 2
# Predicted: 2 Data: (1, 2, 2, 1, 1, 1) Actual: 2
# Predicted: 2 Data: (3, 0, 0, 1, 0, 1) Actual: 2
# Predicted: 2 Data: (3, 3, 3, 0, 1, 2) Actual: 2
# Predicted: 2 Data: (0, 0, 2, 2, 2, 2) Actual: 2
# Predicted: 2 Data: (2, 0, 2, 2, 2, 2) Actual: 2
# Predicted: 2 Data: (0, 2, 0, 1, 2, 1) Actual: 2
# Predicted: 0 Data: (0, 2, 2, 2, 0, 0) Actual: 0
# Predicted: 2 Data: (0, 3, 2, 0, 0, 0) Actual: 2
# Predicted: 2 Data: (2, 3, 0, 1, 2, 0) Actual: 0
# Predicted: 0 Data: (0, 0, 3, 2, 0, 2) Actual: 0
# Predicted: 2 Data: (3, 3, 0, 2, 0, 0) Actual: 2
# Predicted: 2 Data: (3, 3, 3, 1, 0, 0) Actual: 2
# Predicted: 0 Data: (2, 3, 1, 1, 0, 0) Actual: 0
# Predicted: 1 Data: (1, 2, 1, 2, 0, 2) Actual: 1
# Predicted: 0 Data: (2, 2, 3, 1, 2, 2) Actual: 0
# Predicted: 2 Data: (3, 2, 2, 1, 1, 1) Actual: 2
# Predicted: 2 Data: (1, 2, 2, 0, 0, 1) Actual: 2
# Predicted: 0 Data: (2, 0, 2, 2, 0, 0) Actual: 0
# Predicted: 2 Data: (1, 3, 2, 1, 2, 1) Actual: 2
# Predicted: 2 Data: (0, 1, 0, 0, 2, 1) Actual: 2
# Predicted: 2 Data: (2, 2, 1, 2, 1, 1) Actual: 2
# Predicted: 3 Data: (2, 2, 3, 1, 0, 0) Actual: 3
# Predicted: 2 Data: (0, 1, 1, 1, 2, 2) Actual: 2
# Predicted: 2 Data: (3, 1, 2, 2, 0, 1) Actual: 2
# Predicted: 2 Data: (2, 0, 0, 1, 2, 1) Actual: 2
# Predicted: 0 Data: (3, 2, 3, 1, 2, 0) Actual: 0
# Predicted: 2 Data: (2, 1, 3, 1, 1, 1) Actual: 2
# Predicted: 2 Data: (0, 0, 1, 0, 0, 1) Actual: 2
# Predicted: 2 Data: (0, 2, 1, 2, 2, 2) Actual: 2
# Predicted: 0 Data: (0, 1, 1, 1, 0, 2) Actual: 0
# Predicted: 0 Data: (3, 1, 2, 2, 1, 0) Actual: 0
# Predicted: 2 Data: (3, 3, 1, 1, 0, 0) Actual: 2
# Predicted: 0 Data: (1, 3, 3, 2, 2, 0) Actual: 0
# Predicted: 0 Data: (1, 3, 3, 2, 0, 2) Actual: 0
# Predicted: 2 Data: (3, 3, 1, 2, 0, 0) Actual: 2
# Predicted: 2 Data: (0, 2, 0, 0, 1, 0) Actual: 2
# Predicted: 2 Data: (1, 3, 1, 2, 2, 2) Actual: 2
# Predicted: 2 Data: (2, 2, 0, 0, 0, 1) Actual: 2
# Predicted: 0 Data: (2, 1, 1, 1, 0, 0) Actual: 3
# Predicted: 0 Data: (3, 2, 2, 1, 1, 2) Actual: 0
# Predicted: 2 Data: (0, 1, 2, 0, 1, 1) Actual: 2
# Predicted: 2 Data: (3, 0, 2, 2, 2, 1) Actual: 2
# Predicted: 2 Data: (0, 3, 0, 1, 1, 2) Actual: 2
# Predicted: 2 Data: (3, 3, 0, 0, 0, 2) Actual: 2
# Predicted: 2 Data: (2, 2, 3, 0, 0, 1) Actual: 2
# Predicted: 2 Data: (3, 3, 0, 2, 0, 2) Actual: 2
# Predicted: 2 Data: (3, 3, 0, 0, 2, 1) Actual: 2
# Predicted: 0 Data: (0, 0, 3, 1, 0, 0) Actual: 0
# Predicted: 2 Data: (0, 2, 2, 0, 2, 2) Actual: 2
# Predicted: 2 Data: (1, 0, 0, 1, 2, 2) Actual: 0
# Predicted: 2 Data: (3, 1, 2, 1, 2, 1) Actual: 2
# Predicted: 2 Data: (0, 3, 0, 0, 1, 0) Actual: 2
# Predicted: 2 Data: (1, 3, 1, 0, 2, 1) Actual: 2
# Predicted: 2 Data: (0, 0, 0, 1, 0, 2) Actual: 0
# Predicted: 2 Data: (3, 3, 1, 1, 1, 0) Actual: 2
# Predicted: 2 Data: (3, 3, 0, 0, 2, 0) Actual: 2
# Predicted: 0 Data: (0, 1, 2, 1, 1, 2) Actual: 0
# Predicted: 2 Data: (1, 1, 3, 0, 0, 0) Actual: 2
# Predicted: 0 Data: (0, 2, 1, 2, 0, 0) Actual: 0
# Predicted: 0 Data: (3, 2, 2, 2, 0, 2) Actual: 0
# Predicted: 2 Data: (3, 0, 0, 1, 1, 1) Actual: 2
# Predicted: 2 Data: (3, 0, 3, 0, 1, 1) Actual: 2
# Predicted: 2 Data: (1, 1, 1, 2, 2, 1) Actual: 2
# Predicted: 0 Data: (2, 1, 1, 1, 0, 2) Actual: 1
# Predicted: 2 Data: (0, 3, 0, 1, 1, 1) Actual: 2
# Predicted: 2 Data: (3, 2, 0, 1, 0, 1) Actual: 2
# Predicted: 2 Data: (2, 0, 0, 0, 2, 1) Actual: 2
# Predicted: 2 Data: (2, 0, 3, 0, 2, 0) Actual: 2
# Predicted: 2 Data: (0, 0, 2, 0, 1, 1) Actual: 2
# Predicted: 0 Data: (2, 3, 0, 1, 0, 0) Actual: 0
# Predicted: 2 Data: (1, 2, 2, 0, 2, 1) Actual: 2
# Predicted: 0 Data: (2, 2, 3, 2, 0, 2) Actual: 0
# Predicted: 2 Data: (0, 1, 3, 1, 2, 1) Actual: 2
# Predicted: 2 Data: (1, 0, 3, 2, 0, 1) Actual: 2
# Predicted: 2 Data: (1, 2, 0, 1, 2, 0) Actual: 1
# Predicted: 2 Data: (1, 0, 3, 0, 2, 0) Actual: 2
# Predicted: 2 Data: (2, 3, 3, 0, 1, 2) Actual: 2
# Predicted: 0 Data: (1, 2, 0, 1, 1, 0) Actual: 1
# Predicted: 2 Data: (1, 2, 0, 0, 2, 2) Actual: 2
# Predicted: 2 Data: (0, 0, 1, 0, 2, 2) Actual: 2
# Predicted: 0 Data: (2, 3, 2, 1, 0, 2) Actual: 0
# Predicted: 2 Data: (1, 3, 1, 0, 2, 2) Actual: 2
# Predicted: 0 Data: (1, 3, 3, 1, 0, 0) Actual: 0
# Predicted: 2 Data: (3, 2, 0, 1, 1, 2) Actual: 2
# Predicted: 2 Data: (3, 0, 0, 1, 1, 0) Actual: 2
# Predicted: 0 Data: (1, 0, 1, 2, 2, 2) Actual: 0
# Predicted: 1 Data: (1, 1, 3, 2, 0, 2) Actual: 1
# Predicted: 2 Data: (1, 2, 2, 1, 2, 1) Actual: 2
# Predicted: 2 Data: (3, 2, 1, 2, 1, 1) Actual: 2
# Predicted: 2 Data: (0, 3, 0, 2, 2, 2) Actual: 2
# Predicted: 2 Data: (2, 1, 3, 0, 2, 2) Actual: 2
# Predicted: 2 Data: (0, 0, 0, 0, 1, 0) Actual: 2
# Predicted: 2 Data: (0, 3, 3, 0, 1, 1) Actual: 2
# Predicted: 0 Data: (2, 2, 0, 1, 1, 2) Actual: 0
# Predicted: 2 Data: (3, 2, 1, 2, 0, 1) Actual: 2
# Predicted: 2 Data: (2, 0, 1, 0, 0, 2) Actual: 2
# Predicted: 2 Data: (0, 2, 2, 1, 1, 2) Actual: 0
# Predicted: 2 Data: (3, 1, 2, 0, 0, 2) Actual: 2
# Predicted: 2 Data: (0, 3, 0, 0, 2, 1) Actual: 2
# Predicted: 2 Data: (1, 0, 1, 0, 0, 1) Actual: 2
# Predicted: 0 Data: (3, 1, 3, 1, 0, 0) Actual: 0
# Predicted: 0 Data: (1, 1, 0, 1, 0, 2) Actual: 1
# Predicted: 0 Data: (0, 2, 2, 2, 0, 2) Actual: 0
# Predicted: 2 Data: (3, 3, 0, 1, 0, 2) Actual: 2
# Predicted: 2 Data: (1, 1, 0, 2, 1, 1) Actual: 2
# Predicted: 2 Data: (2, 3, 3, 1, 0, 1) Actual: 2
# Predicted: 2 Data: (2, 1, 0, 1, 0, 1) Actual: 2
# Predicted: 2 Data: (2, 2, 1, 0, 1, 0) Actual: 2
# Predicted: 2 Data: (0, 0, 1, 1, 2, 1) Actual: 2
# Predicted: 2 Data: (2, 2, 2, 0, 0, 0) Actual: 2
# Predicted: 2 Data: (3, 0, 1, 0, 0, 2) Actual: 2
# Predicted: 2 Data: (1, 2, 2, 0, 2, 2) Actual: 2
# Predicted: 3 Data: (1, 1, 2, 1, 0, 0) Actual: 3
# Predicted: 2 Data: (2, 2, 1, 0, 2, 2) Actual: 2
# Predicted: 2 Data: (0, 0, 3, 0, 0, 0) Actual: 2
# Predicted: 2 Data: (0, 0, 2, 0, 1, 2) Actual: 2
# Predicted: 2 Data: (0, 2, 3, 0, 0, 0) Actual: 2
# Predicted: 0 Data: (2, 0, 0, 1, 2, 0) Actual: 0
# Predicted: 0 Data: (3, 1, 0, 2, 1, 0) Actual: 0
# Predicted: 2 Data: (2, 0, 2, 0, 0, 0) Actual: 2
# Predicted: 2 Data: (2, 1, 2, 0, 2, 1) Actual: 2
# Predicted: 2 Data: (2, 0, 2, 1, 1, 1) Actual: 2
# Predicted: 2 Data: (3, 0, 2, 2, 0, 1) Actual: 2
# Predicted: 2 Data: (2, 3, 1, 1, 1, 2) Actual: 2
# Predicted: 2 Data: (0, 3, 3, 2, 1, 0) Actual: 2
# Predicted: 2 Data: (2, 0, 3, 2, 2, 1) Actual: 2
# Predicted: 2 Data: (0, 3, 1, 0, 0, 0) Actual: 2
# Predicted: 2 Data: (2, 2, 2, 1, 1, 1) Actual: 2
# Predicted: 2 Data: (0, 3, 3, 1, 2, 0) Actual: 2
# Predicted: 2 Data: (3, 3, 3, 2, 0, 1) Actual: 2
# Predicted: 0 Data: (0, 0, 1, 1, 0, 2) Actual: 0
# Predicted: 2 Data: (3, 2, 0, 1, 2, 2) Actual: 2
# Predicted: 2 Data: (1, 2, 2, 0, 1, 0) Actual: 2
# Predicted: 2 Data: (1, 1, 3, 2, 0, 1) Actual: 2
# Predicted: 2 Data: (1, 0, 0, 2, 2, 1) Actual: 2
# Predicted: 2 Data: (2, 3, 1, 2, 2, 2) Actual: 2
# Predicted: 2 Data: (2, 2, 3, 0, 2, 2) Actual: 2
# Predicted: 2 Data: (2, 1, 0, 2, 2, 0) Actual: 2
# Predicted: 2 Data: (3, 2, 2, 0, 2, 0) Actual: 2
# Predicted: 2 Data: (3, 3, 1, 0, 1, 1) Actual: 2

# %%
# using the names
for i in range(len(predicted)):
    print(f"Predicted: {names[predicted[i]]}       Actual: {names[y_test[i]]}")
# Out:
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: vgood
# Predicted: vgood       Actual: vgood
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: acc
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: unacc       Actual: unacc
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: unacc
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: acc       Actual: acc
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: vgood       Actual: vgood
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: vgood
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: acc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: acc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: acc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: acc       Actual: acc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: unacc       Actual: acc
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: vgood       Actual: vgood
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: unacc       Actual: unacc
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good
# Predicted: good       Actual: good

# %%
# printing the neighbors with distances so see how it predicted those values
#  ie if in test set the value to be predicted is actually "good" then the neighbors around it should be "good" within some distance to view those neighbor and distances we can use sklearn's inbuilt

# %%
for i in range(len(predicted)):
    print(f"Predicted: {names[predicted[i]]}       Actual: {names[y_test[i]]}")
    n=model.kneighbors([x_test[i]],5,True)
    print(f"n {n}")
# Out:
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[  46,  228,  713, 1465,  111]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1094, 1543,   35,  250, 1130]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 289,  351,   22, 1547,  558]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 531, 1185,  450,  536,  624]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 85, 354, 520, 900, 663]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1308,  901,  135,  241,  125]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 304,  424, 1311,  542,  473]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 329, 1162,  395,  939, 1193]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 749, 1235,  105, 1064,  417]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 949,   69,  903,  990, 1135]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[378, 356, 890, 899, 444]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 786, 1529,  186, 1021, 1466]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1480,  377,  501,  879,  567]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 961,  773, 1289, 1445, 1351]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[732, 209, 999, 986, 816]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 691, 1477,  405,  519, 1120]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1186,  491,  185,  959,  148]], dtype=int64))
# Predicted: unacc       Actual: vgood
# n (array([[1., 1., 1., 1., 1.]]), array([[  44, 1058,  238, 1306,   24]], dtype=int64))
# Predicted: vgood       Actual: vgood
# n (array([[1., 1., 1., 1., 1.]]), array([[ 540,  966, 1402,   27,  689]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[432, 655, 894,  13, 198]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 534, 1334, 1045, 1166,  969]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 191, 1530,  173,  364,  182]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 175, 1005,  679,  160,  623]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 373,  700, 1454,  644,  681]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 362,  117,  861, 1350, 1113]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 691,  727,  204,  581, 1257]], dtype=int64))
# Predicted: unacc       Actual: acc
# n (array([[1., 1., 1., 1., 1.]]), array([[1285, 1317, 1323, 1220,  154]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1363, 1095, 1160, 1102, 1157]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 479,   70, 1176,  685,  141]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 780,  868, 1324, 1163,  394]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[  28,   42,    1, 1458,  791]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1309,  953, 1046,  313,   48]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1.        , 1.        , 1.        , 1.        , 1.41421356]]), array([[1019,  329, 1248,  882,  905]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[880, 602, 958, 881, 589]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 724, 1357,  909, 1497,  991]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 694, 1223, 1395, 1068, 1063]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 357, 1478, 1428, 1248, 1136]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 157, 1536,  256, 1297,  102]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 767, 1031, 1146,  438,  932]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[1236, 1213, 1294,  317,  348]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 220, 1313,  204,  657, 1257]], dtype=int64))
# Predicted: good       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[1390,  169, 1531,  993,  189]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 161,  556, 1253,  494,  854]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 456,   24,  389, 1051, 1198]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 720,  598,  738,  499, 1160]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 615,  322,  527, 1505, 1251]], dtype=int64))
# Predicted: acc       Actual: acc
# n (array([[1., 1., 1., 1., 1.]]), array([[1161,  101,  620,  257,  733]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 107,   89, 1341,  318,  331]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 427, 1293,  901,  779, 1430]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 881, 1043, 1142, 1506,  699]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[151, 278, 927, 971, 564]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 880,  286,  827,  523, 1181]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 735, 1387, 1049,  851,  830]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1229, 1517, 1155, 1205,  761]], dtype=int64))
# Predicted: vgood       Actual: vgood
# n (array([[1., 1., 1., 1., 1.]]), array([[ 554, 1168, 1538,  172,  738]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 521,  676, 1171,  337,  109]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1379,  960,  707, 1371,  591]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1084, 1015, 1149,  679,  255]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[1134,  384,  516,  988,  743]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1309,   20, 1263,  464,  997]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 646,  121,  633,   43, 1179]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1300,  701,  775,  216,  497]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 990,  335, 1057,  337, 1482]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[1371,  707, 1534,   97,  542]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1116, 1160,  315,  456,  776]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 474, 1121, 1354,  227,  914]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 928,  177,  371, 1352, 1140]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1.        , 1.        , 1.        , 1.        , 1.41421356]]), array([[ 935, 1505,  383, 1170,  389]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 618,  351,   22,  358, 1273]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 263,  701, 1474, 1033, 1459]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 114, 1291, 1184,  984,  266]], dtype=int64))
# Predicted: unacc       Actual: vgood
# n (array([[1., 1., 1., 1., 1.]]), array([[365, 218, 784, 541, 531]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 832,  171,  336,  388, 1100]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1436,  959, 1520,  572, 1437]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 833, 1109,  256,  370,  102]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 245, 1410, 1032, 1440,  992]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 711,   18, 1082,  614,  867]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 309, 1369, 1538,  484,  725]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1198,  799, 1242,   31,  600]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 359,  181,  940,  931, 1376]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[1334,  137,  128, 1389, 1073]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[870, 663, 252, 629, 804]], dtype=int64))
# Predicted: good       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 782, 1233, 1019,  723,  806]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1061, 1109,  273,  372, 1434]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 584, 1484,  593, 1002,  251]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 695,  937, 1017, 1110,  766]], dtype=int64))
# Predicted: good       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[   3, 1331, 1493,  139,  754]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 383, 1421,   91,  435,  834]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 690,  400,  993, 1531,  280]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[  79,  713,   50,  337, 1186]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1150, 1424,  863,  622,  183]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 178,  655,  294,  174, 1344]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 509,  466,  171,  610, 1460]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1355,  897, 1005,  800,  230]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 112, 1328,  952, 1192,  267]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[850, 818, 995, 925, 885]], dtype=int64))
# Predicted: unacc       Actual: acc
# n (array([[1., 1., 1., 1., 1.]]), array([[1153,  218,  260,  152,  631]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[  93,  979,  583,  251, 1283]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[756, 266, 762, 715, 444]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[544, 116,  38, 468, 718]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 549,  254,  380,  407, 1521]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1133,   68, 1255,  633,  170]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[401, 189, 456,  84, 389]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[804, 354, 881, 334, 523]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[479, 596, 392, 509, 141]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 543, 1177,  763,  891,  305]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 161, 1439, 1076,  895,  941]], dtype=int64))
# Predicted: good       Actual: acc
# n (array([[1., 1., 1., 1., 1.]]), array([[  11,   39, 1498,  767, 1146]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 449,   58,  488, 1408, 1432]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 685, 1176,  790, 1144,  477]], dtype=int64))
# Predicted: unacc       Actual: acc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 538,   72, 1258,  618,  552]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[504, 650, 222, 627, 550]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 515,  506,  529, 1391,  109]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[  40, 1259,   99,   32,  836]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 566, 1477,  550, 1548,  441]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[1030,  805,  942,  316, 1092]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[492, 388, 444, 413, 756]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1227,  224, 1338, 1357,   52]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 925,  850,  329, 1248,  939]], dtype=int64))
# Predicted: acc       Actual: acc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 161,  177, 1253, 1264,  481]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 409, 1368,  912, 1491,  950]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 779,  861, 1495,  341, 1113]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1033,  992, 1474, 1384,  582]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 585,  411, 1261,  312, 1114]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 765,  721,  203,  682, 1451]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 85, 857, 520, 590, 191]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 325, 1104, 1284, 1178, 1490]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 715,  206,  935, 1205,  610]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 360,  361,  260, 1062, 1153]], dtype=int64))
# Predicted: good       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 252,  301,  602,  870, 1274]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1014,  963,   35,  872,  290]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 766,  251,  677,  593, 1017]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1111,  665,  164,  916,  948]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[138, 122, 788, 635, 131]], dtype=int64))
# Predicted: unacc       Actual: acc
# n (array([[1., 1., 1., 1., 1.]]), array([[1467,   23, 1493, 1029,  754]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[ 301, 1236,  539,  298,  265]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[285, 756, 739, 493, 675]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[913, 910, 660, 929, 528]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[207, 738, 725,  32, 284]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[631, 218, 349, 724, 541]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1203,  303,  147,  874, 1222]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1171, 1391, 1324,  905,  780]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[886, 639, 613, 874, 484]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 567, 1122,  501, 1532,  547]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1477,  550,  379,  519,  409]], dtype=int64))
# Predicted: vgood       Actual: vgood
# n (array([[1., 1., 1., 1., 1.]]), array([[1226,    0, 1415,  622,   47]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 454,  918,   45,  875, 1526]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 722,  323, 1509, 1150,  183]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1443,  683,   50,  515, 1374]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[  10, 1091, 1090, 1473,  693]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[  52,  625,  592,   38, 1240]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[1287, 1485, 1304,  936, 1412]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 564, 1543,  244, 1130,  330]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 250, 1475, 1061, 1261,  195]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[760, 156, 464,   9, 957]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 151, 1461,  927,  833,   51]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 726, 1425,  595, 1131,   40]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 474,   94,  340, 1489, 1354]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 256, 1000, 1343, 1197,  888]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 584,  150,  382,  787, 1002]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1202,  681,  832,  167, 1329]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1238,  227, 1054,  985,  812]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1157,  598, 1447,  284,   64]], dtype=int64))
# Predicted: unacc       Actual: unacc
# n (array([[1., 1., 1., 1., 1.]]), array([[395, 882, 121,  43,  71]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1350, 1551,  117, 1339,  325]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 817,  958,  334,  881, 1043]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1166, 1323,  406,  540,  966]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 375,  862,  922,  929, 1492]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[   5,  275,  902, 1425, 1349]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[477, 447, 973, 906, 345]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[ 332,  463,  576,  592, 1027]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1024,  673, 1081, 1085,  743]], dtype=int64))
# Predicted: good       Actual: good
# n (array([[1., 1., 1., 1., 1.]]), array([[1502,   91,  742, 1376,  834]], dtype=int64))

# %%
# we can create a map but that is not of much use so skipping it 
# sklearn documentation can help with it
